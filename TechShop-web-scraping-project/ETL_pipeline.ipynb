# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from sqlalchemy import create_engine

# %%
url = 'https://www.jumia.com.ng/catalog/?q=laptops'

response = requests.get(url)

print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
listings = soup.find_all('div', class_ = 'info')

# %%
names = []
 
for listing in listings:
    name = listing.find('h3', class_ = 'name').text
    names.append(name)

# %%
names
# Out:
# ['Hp Stream 11-Intel Celeron 64gb Ssd/4gb Ram+pouch',
#  'Hp EliteBook 840 G6 Touchscreen Intel Core I5 16GB RAM/512GB SSD/Backlit Keyboard/FP Win 11 Pro',
#  'Hp ProBook 11 X360- TOUCH- 512GB SSD/4GB RAM-Intel CELERON QUAD CORE WIN10 Pro +Mouse &USB Light',
#  'DELL Latitude 3450 Core I3 ITB HDD 8GB RAM Wins 10 + Keyboard Flash Light',
#  'Hp EliteBook 840 G6 Intel Core I5 Touchscreen 16GB RAM/1TB SSD/Backlit Keyboard/FP Win 11 Pro',
#  "Ace Elec ACE 14.1'' Intel Celeron J4105 4Core CPU 16GB+128GB Laptop",
#  'Hp Stream 11 Pro- Intel Celeron - 4GB RAM - 64GB SSD Windows 10 Pro+ Mouse & USB LIGHT FOR Keyboard',
#  "Ace Elec ACE 14.1'' Intel Celeron J4105 4Core CPU 16GB+512GB Laptop",
#  'DELL Latitude 3190 Celeron 128SSD 4GB RAM Wins 10 + Keyboard Flash Light',
#  'Hp EliteBook 840 G6 Intel Core I5-16GB RAM/1TB SSD/Backlit Keyboard/FP Reader Wins 11 Pro Laptop +BAG',
#  'WOZIFAN 14.1"Intel Celeron N4020 6GB+256GB,SSD Support To 1 TB，2.4G+5G Wi-Fi,1920*1080 Laptop Blue',
# ...

# %%
new_prices = []

for listing in listings:
    prices = listing.find("div", class_ = "prc").text
    new_prices.append(prices)

# %%
new_prices
# Out:
# ['₦ 150,000',
#  '₦ 495,500',
#  '₦ 218,000',
#  '₦ 450,000',
#  '₦ 515,000',
#  '₦ 235,000',
#  '₦ 170,000',
#  '₦ 275,000',
#  '₦ 180,000',
#  '₦ 505,000',
#  '₦ 239,258',
#  '₦ 155,000',
#  '₦ 305,000',
#  '₦ 311,596',
#  '₦ 220,000',
#  '₦ 155,000',
#  '₦ 193,000',
#  '₦ 120,000',
#  '₦ 120,000',
#  '₦ 152,000',
#  '₦ 249,500',
#  '₦ 465,000',
#  '₦ 185,000',
#  '₦ 130,000',
#  '₦ 205,000',
#  '₦ 515,000',
#  '₦ 220,000',
#  '₦ 150,000',
#  '₦ 780,000',
#  '₦ 2,500',
#  '₦ 205,000',
#  '₦ 248,449',
#  '₦ 465,000',
#  '₦ 170,000',
#  '₦ 535,000',
#  '₦ 505,000',
#  '₦ 750,000',
#  '₦ 185,000',
#  '₦ 280,000',
#  '₦ 325,000']

# %%
old_price = []
discounted = []

for listing in listings:
    if listing.find("div", class_ = "s-prc-w"):
        price = listing.find("div", class_ = "old").text
        old_price.append(price)
        
        discount = listing.find("div", class_ = "bdg _dsct _sm").text
        discounted.append(discount)
    else:
        old_price.append('None')
        discounted.append('None')

# %%
old_price
# Out:
# ['₦ 180,000',
#  '₦ 770,900',
#  '₦ 800,000',
#  '₦ 500,000',
#  '₦ 770,900',
#  '₦ 799,000',
#  '₦ 200,000',
#  '₦ 1,399,000',
#  '₦ 500,000',
#  '₦ 800,000',
#  '₦ 1,606,500',
#  'None',
#  '₦ 547,000',
#  '₦ 1,699,000',
#  '₦ 600,000',
#  '₦ 250,000',
#  '₦ 220,000',
#  'None',
#  'None',
#  'None',
#  '₦ 250,000',
#  '₦ 800,000',
#  '₦ 295,000',
#  '₦ 160,000',
#  '₦ 398,450',
#  '₦ 770,900',
#  'None',
#  'None',
#  '₦ 900,000',
#  '₦ 20,000',
#  '₦ 410,000',
#  '₦ 1,606,500',
#  '₦ 550,000',
#  '₦ 200,000',
#  '₦ 690,000',
#  '₦ 850,000',
#  '₦ 800,000',
#  'None',
#  '₦ 350,000',
#  'None']

# %%
discounted
# Out:
# ['17%',
#  '36%',
#  '73%',
#  '10%',
#  '33%',
#  '71%',
#  '15%',
#  '80%',
#  '64%',
#  '37%',
#  '85%',
#  'None',
#  '44%',
#  '82%',
#  '63%',
#  '38%',
#  '12%',
#  'None',
#  'None',
#  'None',
#  '1%',
#  '42%',
#  '37%',
#  '19%',
#  '49%',
#  '33%',
#  'None',
#  'None',
#  '13%',
#  '88%',
#  '50%',
#  '85%',
#  '15%',
#  '15%',
#  '22%',
#  '41%',
#  '6%',
#  'None',
#  '20%',
#  'None']

# %%
data = {'Name': names, 'New_Price': new_prices, 'Old_prices': old_price, 'Discounted': discounted}
laptops_df = pd.DataFrame(data)

# %%
laptops_df
# Out:
#                                                  Name  New_Price   Old_prices  \
# 0   Hp Stream 11-Intel Celeron 64gb Ssd/4gb Ram+pouch  ₦ 150,000    ₦ 180,000
# 1   Hp EliteBook 840 G6 Touchscreen Intel Core I5 ...  ₦ 495,500    ₦ 770,900
# 2   Hp ProBook 11 X360- TOUCH- 512GB SSD/4GB RAM-I...  ₦ 218,000    ₦ 800,000
# 3   DELL Latitude 3450 Core I3 ITB HDD 8GB RAM Win...  ₦ 450,000    ₦ 500,000
# 4   Hp EliteBook 840 G6 Intel Core I5 Touchscreen ...  ₦ 515,000    ₦ 770,900
# 5   Ace Elec ACE 14.1'' Intel Celeron J4105 4Core ...  ₦ 235,000    ₦ 799,000
# 6   Hp Stream 11 Pro- Intel Celeron - 4GB RAM - 64...  ₦ 170,000    ₦ 200,000
# 7   Ace Elec ACE 14.1'' Intel Celeron J4105 4Core ...  ₦ 275,000  ₦ 1,399,000
# 8   DELL Latitude 3190 Celeron 128SSD 4GB RAM Wins...  ₦ 180,000    ₦ 500,000
# 9   Hp EliteBook 840 G6 Intel Core I5-16GB RAM/1TB...  ₦ 505,000    ₦ 800,000
# 10  WOZIFAN 14.1"Intel Celeron N4020 6GB+256GB,SSD...  ₦ 239,258  ₦ 1,606,500
# ...

# %% [markdown]
# ## Extraction

# %%
pages = [page for page in range(1, 11)]

names = []
new_prices = []
old_prices = []
discounted = []

for page_num in pages:
    url = f'https://www.jumia.com.ng/catalog/?q=laptops&page={page_num}#catalog-listing'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = soup.find_all('div', class_ = 'info')
    
    for listing in listings:
        
        name = listing.find('h3', class_ = 'name').text
        names.append(name)
        
        prices = listing.find("div", class_ = "prc").text
        new_prices.append(prices)
        
        if listing.find("div", class_ = "s-prc-w"):
            price = listing.find("div", class_ = "old").text
            old_prices.append(price)
            
            discount = listing.find("div", class_ = "bdg _dsct _sm").text
            discounted.append(discount)
        else:
            old_prices.append('None')
            discounted.append('None')
            
data = {'Name': names, 'New_Price': new_prices, 'Old_prices': old_prices, 'Discounted': discounted}
all_laptops_df = pd.DataFrame(data)

# %%
all_laptops_df
# Out:
#                                                   Name  New_Price Old_prices  \
# 0    Hp Stream 11-Intel Celeron 64gb Ssd/4gb Ram+pouch  ₦ 150,000  ₦ 180,000
# 1    Hp EliteBook 840 G6 Touchscreen Intel Core I5 ...  ₦ 495,500  ₦ 770,900
# 2    Hp ProBook 11 X360- TOUCH- 512GB SSD/4GB RAM-I...  ₦ 218,000  ₦ 800,000
# 3    DELL Latitude 3450 Core I3 ITB HDD 8GB RAM Win...  ₦ 450,000  ₦ 500,000
# 4    Hp EliteBook 840 G6 Intel Core I5 Touchscreen ...  ₦ 515,000  ₦ 770,900
# ..                                                 ...        ...        ...
# 395  Hp Notebook 15 Intel Core I3 (8GB RAM, 1TB HDD...  ₦ 560,000  ₦ 800,000
# 396     DELL CHROMEBOOK, 4GB RAM, 16GB SSD + 32GBFLASH  ₦ 120,000       None
# 397  Hp Stream 14 Intel Celeron 4GB, 64GB SSD Wins ...  ₦ 185,000       None
# 398  DELL Latitude 7490 TOUCHSCREEN Intel Core I7- ...  ₦ 650,000  ₦ 876,000
# 399  Asus NOTEBOOK 14 INTEL CELERON N4020 4GB RAM 1...  ₦ 359,400  ₦ 395,000
#
#     Discounted
# 0          17%
# ...

# %% [markdown]
# ## Transformations

# %%
data_copy = all_laptops_df.copy()

# %%
# Function to clean price values
def clean_price(price):
    if pd.isna(price):
        return None
    return price.replace('₦', '').replace(',', '').strip()

# Clean 'New_Price' and 'Old_prices' columns
data_copy['New_Price'] = data_copy['New_Price'].apply(clean_price)
data_copy['Old_prices'] = data_copy['Old_prices'].apply(clean_price)

# %%
data_copy['Discounted'] = data_copy['Discounted'].apply(lambda x: int(x.replace('%', '').strip()) if pd.notna(x) and x != 'None' else None)

# %%
data_copy
# Out:
#                                                   Name New_Price Old_prices  \
# 0    Hp Stream 11-Intel Celeron 64gb Ssd/4gb Ram+pouch    150000     180000
# 1    Hp EliteBook 840 G6 Touchscreen Intel Core I5 ...    495500     770900
# 2    Hp ProBook 11 X360- TOUCH- 512GB SSD/4GB RAM-I...    218000     800000
# 3    DELL Latitude 3450 Core I3 ITB HDD 8GB RAM Win...    450000     500000
# 4    Hp EliteBook 840 G6 Intel Core I5 Touchscreen ...    515000     770900
# ..                                                 ...       ...        ...
# 395  Hp Notebook 15 Intel Core I3 (8GB RAM, 1TB HDD...    560000     800000
# 396     DELL CHROMEBOOK, 4GB RAM, 16GB SSD + 32GBFLASH    120000       None
# 397  Hp Stream 14 Intel Celeron 4GB, 64GB SSD Wins ...    185000       None
# 398  DELL Latitude 7490 TOUCHSCREEN Intel Core I7- ...    650000     876000
# 399  Asus NOTEBOOK 14 INTEL CELERON N4020 4GB RAM 1...    359400     395000
#
#      Discounted
# 0          17.0
# 1          36.0
# ...

# %% [markdown]
# ## Loading

# %%
# loading

db_url = f"postgresql://{db_params['username']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}"

engine = create_engine(db_url)

with engine.connect() as conn:
    all_laptops_df.to_sql('jumia_laptops', conn, index=False, if_exists='replace')
    
print('Data loaded successfully')
# Out:
# Data loaded successfully
